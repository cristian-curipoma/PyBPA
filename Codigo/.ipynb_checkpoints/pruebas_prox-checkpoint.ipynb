# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from bpapy.Get_data import Get_dry_data, Get_prox_data, Get_elem_data

# %%
Secado = Get_dry_data('./Datos/Secado/secado_sol_aguacate1.csv', ';')

df_dry = Secado.Get_dry_df(repeats=3, surfaces=['Cemento', 'Tierra', 'Cesped'], lengths=['10 cm', '20 cm', '30 cm'])

# %%
sec_est_agua = Get_dry_data('./Datos/Secado/secado_estufa_aguacate.csv', ';')
sec_est_hojas_agua = Get_dry_data('./Datos/Secado/secado_hojas_estufa_aguacate.csv', ';')

# %%
df_dry_est_ma = sec_est_agua.Get_dry_df(repeats=3, surfaces=['Metal'], lengths=['10 cm', '20 cm', '30 cm'])
df_dry__est_ha = sec_est_hojas_agua.Get_dry_df(repeats=2, surfaces=['Metal'], lengths=['Unique'])

# %%
y = df_dry.loc['10 cm', 'Cemento'].mean()
x = np.linspace(0,len(y),len(y), endpoint = False)
plt.plot(x,y)
plt.title('Drying Behavior of abocato wood (10 cm over buildingrock) throught time')
plt.xlabel('Time [h]')
plt.ylabel('Weight of biomass [g]')
# Out:
# Text(0, 0.5, 'Weight of biomass [g]')

# %%
est = Get_prox_data('./Datos/Analisis_proximal/prox_humedad_aguacate_madera-hojas.csv', ';')

# %%
esr = Get_elem_data('./Datos/Analisis_elemental/aguacate_elemental.csv', ';')

# %%
esr.Get_df_elem(repeats=3, biomass=['Abocato'], essays= ['0% hojas & 100% madera',
 '10% hojas & 90% madera',
 '20% hojas & 80% madera',
 '30% hojas & 70% madera',
 '40% hojas & 60% madera',
 '50% hojas & 50% madera',
 '100% hojas & 0% madera'])
# Out:
#                                              Weight [mg]  C [%]  N [%]  H [%]  \
# Essay                  Biomass Repeticion
# 0% hojas & 100% madera Abocato Repeticion 1        21.34  45.94   0.69  4.475
#                                Repeticion 2        19.71  46.22   0.71  4.441
#                                Repeticion 3        21.17  46.37   0.72  4.547
# 10% hojas & 90% madera Abocato Repeticion 1        21.13  46.58   0.86  4.587
#                                Repeticion 2        21.36  46.45   0.85  4.612
#                                Repeticion 3        22.68  46.03   0.85  4.653
# 100% hojas & 0% madera Abocato Repeticion 1        21.79  47.05   2.35  4.807
#                                Repeticion 2        21.12  47.08   2.32  4.756
#                                Repeticion 3        19.27  47.08   2.31  4.651
# 20% hojas & 80% madera Abocato Repeticion 1        20.44  46.51   1.02  4.581
#                                Repeticion 2        20.33  46.47   1.01  4.553
#                                Repeticion 3        20.85  46.49   1.04  4.574
# 30% hojas & 70% madera Abocato Repeticion 1        20.76  45.76   1.19  4.510
#                                Repeticion 2        20.55  46.32   1.17  4.597
#                                Repeticion 3        20.48  45.45   1.13  4.460
# 40% hojas & 60% madera Abocato Repeticion 1        20.84  46.62   1.43  4.661
#                                Repeticion 2        21.02  46.48   1.43  4.654
#                                Repeticion 3        20.73  46.72   1.41  4.661
# 50% hojas & 50% madera Abocato Repeticion 1        19.63  46.85   1.51  4.596
#                                Repeticion 2        20.22  46.63   1.55  4.633
#                                Repeticion 3        20.14  46.43   1.57  4.593
#
#                                              S [%]  C/N ratio  C/H ratio
# Essay                  Biomass Repeticion
# 0% hojas & 100% madera Abocato Repeticion 1  0.000    66.2299    10.2658
#                                Repeticion 2  0.000    64.7641    10.4076
#                                Repeticion 3  0.000    64.3494    10.1961
# 10% hojas & 90% madera Abocato Repeticion 1  0.000    54.3270    10.1555
#                                Repeticion 2  0.000    54.9159    10.0707
#                                Repeticion 3  0.000    54.2820     9.8928
# 100% hojas & 0% madera Abocato Repeticion 1  0.138    19.9869     9.7887
#                                Repeticion 2  0.136    20.3332     9.8983
#                                Repeticion 3  0.112    20.4226    10.1241
# 20% hojas & 80% madera Abocato Repeticion 1  0.000    45.7805    10.1523
#                                Repeticion 2  0.000    45.8489    10.2054
#                                Repeticion 3  0.009    44.6432    10.1638
# 30% hojas & 70% madera Abocato Repeticion 1  0.019    38.4681    10.1478
#                                Repeticion 2  0.001    39.7229    10.0762
#                                Repeticion 3  0.000    40.1293    10.1916
# 40% hojas & 60% madera Abocato Repeticion 1  0.031    32.5790    10.0024
#                                Repeticion 2  0.046    32.6112     9.9876
#                                Repeticion 3  0.029    33.1584    10.0232
# 50% hojas & 50% madera Abocato Repeticion 1  0.049    31.0316    10.1937
#                                Repeticion 2  0.026    30.0522    10.0640
#                                Repeticion 3  0.042    29.6365    10.1075

# %%
est.Get_df_prox(repeats=3, biomass=['Abocato'], essays= ['0% hojas & 100% madera',
 '10% hojas & 90% madera',
 '20% hojas & 80% madera',
 '30% hojas & 70% madera',
 '40% hojas & 60% madera',
 '50% hojas & 50% madera',
 '100% hojas & 0% madera'])

# %%
essays = ['{0}% hojas & {1}% madera'.format(i, 100 - i) for i in range(0,101,10)]
essays

# %%
['0% hojas & 100% madera',
 '10% hojas & 90% madera',
 '20% hojas & 80% madera',
 '30% hojas & 70% madera',
 '40% hojas & 60% madera',
 '50% hojas & 50% madera',
 '100% hojas & 0% madera']
